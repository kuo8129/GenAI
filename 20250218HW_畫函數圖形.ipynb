# %% [markdown]
# <a href="https://colab.research.google.com/github/kuo8129/GenAI/blob/main/20250218HW_%E7%95%AB%E5%87%BD%E6%95%B8%E5%9C%96%E5%BD%A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 匯入基本套件

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 設定數學函數
# * 設定角度theta從0到2𝜋共切成1000個點
# * 讓圖形產生五個平滑的突起，形成五角星星
# * x, y將極座標轉換成直角座標

# %%
theta = np.linspace(0, 2*np.pi,1000)
r = 1 + 0.25 * np.sin(5 * theta)
x = r * np.cos(theta)
y = r * np.sin(theta)

# %% [markdown]
# # 設定顏色漸層
# * 讓y值最小的點(最下方)對應到最深的顏色，y值最大的點(最上方)對應到最淺的顏色
# * 設定透過改變y值來影響autumn顏色漸層

# %%
norm = plt.Normalize(vmin=np.min(y), vmax=np.max(y))
colors = plt.cm.autumn(norm(y))

# %% [markdown]
# # 繪製圖表
# 圖形設置
#  * 用for迴圈讓圖形產生漸層顏色
#  * 更改線條粗細與透明度製造出光暈效果
#
# 圖表設置
#  * 設定標題文字格式
#  * 使xy軸比例相等，避免圖形變形
#  * 設定格線樣式

# %%
# 圖形設置
plt.figure(figsize=(5,5))
for i in range(len(x) - 1):
    plt.plot(x[i:i+2], y[i:i+2], color=colors[i], linewidth=2)
plt.plot(x, y, color='gold', linewidth=6, alpha=0.3)

# 圖表設置
plt.title("Smooth Star", fontsize=14, fontweight='bold', color='orange', loc='center')
plt.axis('equal')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5)
plt.show()
