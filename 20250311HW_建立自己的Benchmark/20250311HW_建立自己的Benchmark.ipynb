# %% [markdown]
# <a href="https://colab.research.google.com/github/kuo8129/GenAI/blob/main/20250311HW_%E5%BB%BA%E7%AB%8B%E8%87%AA%E5%B7%B1%E7%9A%84Benchmark/20250311HW_%E5%BB%BA%E7%AB%8B%E8%87%AA%E5%B7%B1%E7%9A%84Benchmark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 緣起
#
# 隨著AI技術快速發展，各行各業紛紛嘗試導入AI來降低人力與時間成本，在心理諮商輔導領域也不例外，許多學者致力於訓練AI，使其能夠聽懂人類的情感、理解個案，甚至是代理諮商師，以解決心理諮商資源不足的困境。然而，對於透過文字計算機率生成回應的生成式AI來說，其回應品質令人存疑，更不用說在諮商過程中還有很多非語言訊息須一併納入考量，更是生成式AI難以捕捉到的資訊。因此，作為相關領域背景的我，設計了一組題目來測試不同模型對於心理諮商概念的詮釋，作為初步評估生成式AI在心理諮商輔導領域中應用的潛力之參考。

# %% [markdown]
# # 題目
#
# 1. 請問在諮商心理學的領域中，"個案概念化"所代表的意思是什麼？
#
# 2. 你是一位專業的諮商心理師，請你根據以下個案的陳述進行個案概念化。<br>
# 我已經加班好幾天了，工作總是多到做不完，但老闆總是覺得我做的還不夠多，不是批評就是一直催我趕進度，我真的覺得壓力好大，好想大叫，
# 我很想把事情做好讓老闆滿意，但我不知道為什麼我就是沒辦法很專心在工作上，恍恍惚惚，飯也吃不太下，有時候買個麵包、泡個泡麵就一餐
# 了。平常基本上我們都是自己忙自己的，同事之間沒有太多交流，就算有，我也覺得他們不懂我，我不會想跟他們說心事。晚上下班，我常常一個
# 人坐在附近的公園裡發呆，什麼事都不想做，有時候也不知道為什麼，就會莫名哭了起來，走在路上，也在想自己要是發生了什麼意外，會不會就
# 不用工作了，老闆是不是就會放過我了。我知道晚睡不好，但是我真的睡不著，滿腦子都是工作和老闆的樣子，好不容易睡著，又彷彿不到十分鐘
# 鬧鐘就響了，我好累，每天好像就只有睡著的那片刻可以稍微喘口氣，只要一睜開眼睛就覺得好窒息。
#
# 3. 請你根據個案概念化的結果，擬定下一次晤談的方向(短期首要目標)
#
# 4. 請問要如何評估個案的自殺或自傷風險，以及憂鬱症的可能？

# %% [markdown]
# # 分析
#
# ###### 1. 在諮商心理學的領域中，"個案概念化"代表的意思？
#
# * **GPT-4o：**
# 清楚且完整地解釋"個案概念化"的概念，包含：資料收集、分析與計畫等，以及個案概念化對於諮商的作用。
#
# * **Gemini 2.0 Flash：**
# 有指出"個案概念化"的概念，但第三點的促進諮商效果較不適合在此部分進行說明，比較像是個案概念化所能帶來的影響，因此，我會認為這樣的解釋有些失焦，略嫌可惜。
#
# * **Claude 3.7 Sonnet：**
# 解釋稍嫌簡略且不直觀，有點像是以大綱來呈現，而沒有詳細說明各個部分的涵義。此外，部分用詞也不是本國用語，在台灣，多以"個案"或"當事人"來稱呼，而不會用"來訪者"、使用"訊息"而非"信息"。
#
# ---
#
# ###### 2. 根據個案的陳述進行個案概念化。
#
# * **GPT-4o：**
# 我很欣賞其使用個案自述的語言來撰寫，如此能更真實反映出個案的狀態，而不會因為個人的解讀而有所偏離，這是與其他兩個模型較為不同之處。同時，在情緒、認知、行為三個方面皆有完整指出個案的狀況，且有提出適當的諮商目標與介入策略。
#
# * **Gemini 2.0 Flash：**
# 我認為它的分析主要關注於個案的情感面，包含情緒困擾、缺乏支持系統等，在認知與行為面上著墨較少，略嫌可惜。此外，在諮商策略的部分也有些籠統，從文字上較感覺不出有針對個案特定的狀況進行客製化的專業規劃。
#
# * **Claude 3.7 Sonnet：**
# 大致來說有把個案的陳述依照情緒、認知、生理、行為四個層面來分析，但我認為有些部分有點過度解釋，例如：維持因素第三點提及的循環模式，雖然看似合理，但壓力與效率下降的關聯性仍有待確認。不過，我認為它最後有寫到後續評估需求（對個案進一步地了解）很值得學習，會針對個案的自述再更深入地瞭解，以更完整地評估個案的狀況，這是其他兩個AI所沒有提及到的。
#
# ---
#
# ###### 3. 根據個案概念化的結果，擬定下一次晤談的方向(短期首要目標)
#
# * **GPT-4o：**
# 我認為它撰寫的目標優先順序適當，從風險評估到情緒與壓力調節，再到支持系統探索，先解決個案急迫性的問題，再討論後續的解決方式，對於整個諮商過程應會更加有效，此外，相較起其他兩個模型，它擬定的目標也較實際可行、份量適當，緊扣我所下的prompts。
#
# * **Gemini 2.0 Flash：**
# 我認為建立安全信任的諮商關係對於諮商師來說是非常基本的，不需要花費一個段落來敘述這件事，且在面對可能有自殺或自傷風險的個案時，我認為風險評估應為首要目標，放到最後注意事項才提及有點本末倒置了。
#
# * **Claude 3.7 Sonnet：**
# 我覺得針對不同面向都有規劃固然是好事，但由於我所下的prompts是針對下一次的晤談，因此依我來看會覺得其訂定的目標有點太多，可能難以在單次晤談中做完問題來源釐清、目標設定、計畫擬定與練習等。
#
# ---
#
# ###### 4. 如何評估個案的自殺或自傷風險，以及憂鬱症的可能？
#
# * **GPT-4o：**
# 針對自殺風險評估的部分，我覺得它的優點是會針對各個向度舉例，讓人能立即明確瞭解如何進行評估，此外，它也有提供篩檢工具可輔助判斷，並指出後續的處理方式。另外，它也是唯一有針對自傷、非自殺目的的自傷多加說明的模型，而這部分是我原本沒有想到的，但卻也值得提出與個案進行討論的部分。
# 在憂鬱症評估的部分，從DSM-5的準則到量表評估我認為它都介紹很完整，能讓人清楚瞭解評估方式。
#
# * **Gemini 2.0 Flash：**
# 針對自殺風險評估的部分，我蠻喜歡它所列出的六個向度(頻率、持續時間、強度、計畫、手段、意圖)，這與我的學習經驗相似，加上評估危險與保護因子，能更有系統性地評估個案身處的狀態。
# 然而，我認為其在憂鬱症評估的部分就比較不足，沒有提到DSM診斷準則，只有針對症狀列點，對於評估方式也著墨不多、過於簡略。
#
# * **Claude 3.7 Sonnet：**
# 針對自殺風險評估的部分，雖然它有提及評估方式，但我覺得其撰寫的方式有些籠統，而沒有明確指出需要評估的項目。
# 針對憂鬱症評估的部分，雖然有提及DSM-5與ICD-11，但沒有將診斷準則詳細列出就稍嫌可惜，可能只能透過其提供的評估工具來進行衡量。

# %% [markdown]
# # 總結
#
# 整體而言，對於這組題目，我個人偏好GPT-4o的回答，除了它能清楚且完整地回應我的prompts外，在版面編排上也較有條理，並會將重點以粗體標示出來。
